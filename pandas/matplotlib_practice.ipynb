# %% [markdown]
# <a href="https://colab.research.google.com/github/YohanDev99/python-practice/blob/main/pandas/matplotlib_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ✅ Matplotlib을 이용한 시각화

# %% [markdown]
# ### 🖇️ Matplotlib
# * Matplotlib : Python 2D 플로팅 라이브러리
# * 플랫폼에 독립적인 대화형 환경을 제공하며 고품질의 그림을 생성할 수 있게 해준다.

# %% [markdown]
# ### 🖇️ 패키지 임포트 및 기본 설정
# * Matplotlib로 그래프를 그리기 위한 라이브러리 import
# * %matplotlib inline -> notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해준다.
# * %config InlineBackend.figure_format = 'retina' -> 그래프를 더 높은 해상도로 그려준다.

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print("Matplotlib 버전 : ", matplotlib.__version__)
# Out:
# Matplotlib 버전 :  3.7.1

# %% [markdown]
# ### 🖇️ 그래프 객체
# * Figure 객체 : Matplotlib에서 그래프를 그리기 위한 객체(그림을 그릴 도화지)
# * Figure를 subplot( )로 분할해 각 부분에 그래프를 시각화한다.

# %% [markdown]
# ### 🖇️ subplot( )으로 서브플롯 추가
# * subplot( ) : 현재 figure(도화지) 객체에 서브플롯을 추가한다.
# * matplotlib.pyplot.subplot(*args, **kwargs)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0, 10, 0.01)

plt.subplot(2,1,1); plt.plot(x, np.sin(x))
plt.subplot(2,2,3); plt.plot(x, np.cos(x))
plt.subplot(2,2,4); plt.plot(x, np.sin(x)*np.cos(x))

# %% [markdown]
# ### 🖇️ subplot( )으로 서브플롯 집합 추가
# * subplot() : 현재 figure객체에 서브플롯 집합 추가
# * figure 객체와 axes.Axes(Axes객체 또는 Axes객체들 배열)을 반환

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0, 10, 0.01)

fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0,0].plot(x, np.sin(x)); axes[0,1].plot(x, np.cos(x))
axes[1,0].plot(x, np.tanh(x)); axes[1,1].plot(x, np.sin(x)*np.cos(x))

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 7, 0.01)

# %%
def sin_cos(x) :
    return np.sin(x)*np.cos(x)

# %%
func_list = [np.sin, np.cos, np.tanh, sin_cos]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
for i, ax in enumerate(axes.flat):
    ax.plot(x, func_list[i](x))
plt.show()

# %%
fig, axes = plt.subplots(nrows=4)
for i, ax in enumerate(axes.flat):
    ax.plot(x, func_list[i](x))
plt.show()

# %%
fig, axes = plt.subplots(ncols=4)
for i, ax in enumerate(axes.flat):
    ax.plot(x, func_list[i](x))
plt.show()

# %% [markdown]
# ### 🖇️ plot( )
# plot( ) : 주어진 x, y 값을 선(lines)과 점(markers)으로 표시해준다.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0, 10, 0.6)
y = np.sin(x)
fig, axes = plt.subplots(2, 2, figsize=(8, 5))
fig.suptitle('figure sample plots')
axes[0,0].plot(y) # 선그래프, 점 없음, x축은 range(len(y))
axes[0,1].plot(x,y,'ro:') # red(r), 원(o), 점선(:)
axes[1,0].plot(x, np.cos(x), 'cs-.') # cyan(c), square(s), 대시닷(-.)
axes[1,1].plot([3,6], [3,5], 'b^:') # 파랑(b), 세모(^), 점선(:)
axes[1,1].plot([4,5], [5,4], 'kx--') # 검정(k), X(x), 대시선(--)
plt.show()

# %% [markdown]
# ### 🖇️ scatter( )
# * scatter()함수는 산점도 그래프를 그려준다.

# %%
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
plt.scatter(x=iris.petal_length, y=iris.petal_width,
            s=iris.sepal_length*10, c=iris.sepal_width, alpha=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(7902)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ### 🖇️ bar( ), barh( ), axvline( ), axhline( )
# * bar( ) : 수직 막대 그래프
# * barh( ) : 수평 막대 그래프
# * axvline( ) : 수직선
# * axhline( ) : 수평선

# %%
fig, axes = plt.subplots(2,2)
axes[0,0].bar([1,2,3], [3,4,5])
axes[0,1].barh([1,3,5], [1,2,3])
axes[1,0].axvline(0.6)
axes[1,1].axhline(0.4)
plt.show()

# %% [markdown]
# ### 🖇️ hist( )
# * hist( ) : 히스토그램을 그려주며 동시에 히스토그램 값을 함께 반환한다.
# * 데이터의 분포를 확인할 수 있는 가장 좋은 방법 중 하나는 히스토그램을 그리는 것이다.

# %%
# 히스토그램은 x값에 대한 y값을 막대그래프로 표현하는 것과 다르다.
# bins속성으로 구간을 지정하고 해당 구간에 속하는 값들을 히스토그램으로 표현하는 것이다.

fig, axes = plt.subplots(2,2)
axes[0,0].hist(iris.sepal_length, bins=10, color='r')
axes[0,1].hist(iris.sepal_length, bins=15, cumulative=True)
axes[1,0].hist(iris.sepal_length, bins=5, orientation='horizontal')
axes[1,1].hist(iris.sepal_length, bins=10, histtype='step')
plt.show()

# %% [markdown]
# ## ✅ 그래프 커스터마이징

# %% [markdown]
# ### 🖇️ linestyle, linewidth
# * 선의 스타일과 굵기

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.cos(x)

# %%
fig, axes = plt.subplots(2,2)
axes[0,0].plot(x, y, linewidth=2, color="#FF00FF")
axes[0,1].plot(x, y, linestyle="dotted", linewidth=7, color="purple")
axes[1,0].plot(x, y, ls="--", lw=3, c="r")
axes[1,1].plot(x, y, "b,")
plt.show()

# %% [markdown]
# ### 🖇️ text( ), annotate( )
# * 텍스트 표현

# %%
fig, axes = plt.subplots(1,2)
axes[0].scatter(x, y, marker=".")
axes[0].text(2, 0, "Example Gragph", style="italic")
axes[1].scatter(x, y, marker="*")
axes[1].annotate("sine", xy=(5, 0.5), xytext=(2, 0.75),
                 arrowprops=dict(arrowstyle="->", connectionstyle="angle3"))
plt.show()

# %% [markdown]
# ### 🖇️ 수학 기호

# %%
x = np.linspace(0, 10, 100)
y = np.cos(x)

# %%
plt.scatter(x, y, marker=".")
plt.text(3, 0.5, r"$\sum_{i=0}^\infty X_i$", fontsize=20)
plt.show()

# %% [markdown]
# ### 🖇️ 축과 눈금
# * 축(Axis)과 눈금(Tick)은 Artist 클래스를 상속
#     * X축과 Y축은 Axis 클래스를 상속
#     * X축 눈금과 Y축 눈금은 Tick 클래스를 상속
# * 축과 눈금의 지정
#     * Axis 클래스의 set_x???( ) 메서드를 이용 X축의 스타일을 지정
#     * XAxis 클래스의 set_???( ) 메서드를 이용해서도 X축의 스타일을 지정

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = np.cos(x)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8,5))
plt.subplots_adjust(hspace=0.4, wspace=0.3)
axes[0,0].scatter(x, y, marker=".")
axes[0,0].set(title="An Example Axes", ylabel="Y-Axis", xlabel="X-Axis")
axes[0,1].scatter(x, y, marker="^", c="r")
axes[0,1].set_xlim(0,5)
axes[0,1].set_ylim(-2,2)
axes[0,1].set_xlabel("X 0~5")
axes[0,1].set_ylabel("Y -2~2")

axes[1,0].scatter(x, y, marker=".", c="c")
axes[1,0].set(xticks=range(1,8,2),
              xticklabels=[3,100,-12,"foo"],
              yticks=[-2,0,1,2],
              yticklabels=[-200,0,100,"Max"])

axes[1,1].scatter(x, y, marker="v", c="b")
axes[1,1].set_xticks(range(1,8,2))
axes[1,1].set_xticklabels([3,100,-12,"foo"])
axes[1,1].set_yticks([-2,0,1,2])
axes[1,1].set_yticklabels([-200,0,100,"Max"])
axes[1,1].spines['top'].set_visible(False)
axes[1,1].spines['bottom'].set_position(("outward", 10))
axes[1,1].grid(True)
plt.show()

# %% [markdown]
# ### 🖇️ 축 공유
# * 하나의 그래프 영역에 두 개 이상의 그래프를 그리면서 다른 축을 지정하고 싶을 경우 twinx( ), twiny( )로 새로운 축 객체를 생성하여 그래프를 그리고 축을 다르게 지정할 수 있다.
# * twinx( ) 함수는 x축을 공유하고 y축을 오른쪽에 표시해주는 새로운 축 객체를 반환한다.
# * twiny( ) 함수는 y축을 공유하고 x축을 왼쪽에 표시해주는 새로운 축 객체를 반환한다.

# %%
import numpy as np
x = np.arange(0, 10)
y1 = 0.5 * x**2
y2 = -1 * y1

# %%
fig, ax1 = plt.subplots()
ax1.plot(x, y1, 'g^:')
ax1.set_xlabel('X data')
ax1.set_ylabel('Y1 data', color='g')

ax2 = ax1.twinx()
ax2.plot(x, y2, 'bv--')
ax2.set_ylabel('Y2 data', color='b')

ax3 = ax1.twiny()
ax3.plot(-x, y1, 'ro-.')
ax3.set_xlabel('-X data', color='r')

plt.show()

# %% [markdown]
# ### 🖇️ 그래프 제목과 축 제목
# * plot.subtitle( ) 함수는 그래프의 제목을 설정한다.
# * axes.Axes.set_title( ) 함수는 그래프 영역 안에서 축의 제목을 설정한다.

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3))
plt.subplots_adjust(hspace=0.4, wspace=0.3)
plt.suptitle("Main Title")
axes[0].set_title("Title 1")
axes[0].set_xlabel("W")
axes[1].set_title("Title 2", loc='right')
axes[1].set_xlabel("X")
plt.show()

# %% [markdown]
# ### 🖇️ 범례 표시
# * 범례를 표시하는 가장 좋은 방법은 그래프 함수에 의해 범례가 자동으로 그려지게 하는 방법
# * legend( ) 함수는 plot( ) 함수가 label 속성을 가질 경우 함수의 호출만으로 범례를 표시한다.
# * plot( ) 함수에 label 속성을 지정하지 않을 경우 legend( ) 함수의 labels 파라미터를 이용해서 범례의 레이블(이름)을 지정한다.

# %%
import numpy as np
x = np.arange(0, 10)
y = 0.5 * x**2

# %%
plt.style.use('default')
fig, ax1 = plt.subplots(figsize=(8,4))
ax1.plot(x, y, 'g^:', label='GREEN')
ax1.plot(x, -y, 'bv-.', label='BLUE')
ax1.legend() # label 속성 값을 미리 지정했다면 legend() 함수 호출만으로 범례를 나타낼 수 있다.
plt.show()

# %%
# plot() 함수에 label 속성을 지정하지 않았다면 legend() 함수의 labels 파라미터를 이용하여 범례의 레이블(이름)을 지정할 수 있다.
plt.style.use('default')
fig, ax1 = plt.subplots(figsize=(8,4))
ax1.plot(x, y, 'g^:')
ax1.plot(x, -y, 'bv-.')
ax1.legend(labels=["GREEN", "BLUE"])
plt.show()

# %% [markdown]
# ### 🖇️ 그래프 저장

# %%
x = np.linspace(0, 10, 100)
y = np.cos(x)

# %%
fig, ax = plt.subplots()
ax.scatter(x,y, marker=".")
ax.set_title(r"$sigma_i=15$", fontsize=30)
ax.grid(True)
plt.savefig("foo.png", transparent=True)
